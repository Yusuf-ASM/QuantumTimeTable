# %%
import os
import json
import matplotlib.pyplot as plt

# %%
save_path = "./new/shots_solutions"
layers = [3, 5, 7, 10]
colors = ["black", "blue", "crimson","teal"] 

path = "../results/json/simulation/6"
files = os.listdir(path)
files.sort()
temp = files.pop(0)
files.append(temp)
for i in range(len(files)):
    files[i] = path+"/"+files[i]

path = "../results/json/simulation/16"
files16 = os.listdir(path)
files16.sort()
temp = files16.pop(0)
files16.append(temp)
for i in range(len(files)):
    files16[i] = path+"/"+files16[i]

path = "../results/json/simulation/24"
files24 = os.listdir(path)
files24.sort()
temp = files24.pop(0)
files24.append(temp)
for i in range(len(files)):
    files24[i] = path+"/"+files24[i]

# %%
results = []
results16 = []
results24 = []
for i in range(len(files)):
    results.append(json.load(open(str(files[i]))))
    results16.append(json.load(open(str(files16[i]))))
    results24.append(json.load(open(str(files24[i]))))

# %%
xy6 = {3: {5120: 0, 10240: 0, 20480: 0, 30720: 0}, 5: {5120: 0, 10240: 0, 20480: 0, 30720: 0},
       7: {5120: 0, 10240: 0, 20480: 0, 30720: 0}, 10: {5120: 0, 10240: 0, 20480: 0, 30720: 0}}
xy16 = {3: {5120: 0, 10240: 0, 20480: 0, 30720: 0}, 5: {5120: 0, 10240: 0, 20480: 0, 30720: 0},
        7: {5120: 0, 10240: 0, 20480: 0, 30720: 0}, 10: {5120: 0, 10240: 0, 20480: 0, 30720: 0}}
xy24 = {3: {5120: 0, 10240: 0, 20480: 0, 30720: 0}, 5: {5120: 0, 10240: 0, 20480: 0, 30720: 0},
        7: {5120: 0, 10240: 0, 20480: 0, 30720: 0}, 10: {5120: 0, 10240: 0, 20480: 0, 30720: 0}}


for i in results:
    xy6[i["layers"]][i['shots']] = i["solution_count"]/i['shots']

for i in results16:
    xy16[i["layers"]][i['shots']] = i["solution_count"]/i['shots']

for i in results24:
    xy24[i["layers"]][i['shots']] = i["solution_count"]/i['shots']

xy6
# Out:
# {3: {5120: 0.25,
#   10240: 0.23388671875,
#   20480: 0.24228515625,
#   30720: 0.2540690104166667},
#  5: {5120: 0.396484375,
#   10240: 0.39814453125,
#   20480: 0.408935546875,
#   30720: 0.4064127604166667},
#  7: {5120: 0.357421875,
#   10240: 0.482421875,
#   20480: 0.48837890625,
#   30720: 0.487890625},
#  10: {5120: 0.4818359375,
#   10240: 0.4904296875,
#   20480: 0.495751953125,
#   30720: 0.4962890625}}

# %%
for layer, color in zip(layers, colors):
    plt.figure()
    x = list(xy6[layer].keys())
    y = list(xy6[layer].values())
    plt.plot(x, y, color=color, label=f'6Q - {layer} layer', ls="-", marker="o")
    plt.xlabel("No. of P-layers")
    plt.ylabel("No. of Minimization Iterations")
    plt.savefig(save_path+f"/6_{layer}_shots-solution.eps", format='eps')
    plt.legend()

plt.figure()
for layer, color in zip(layers, colors):
    x = list(xy6[layer].keys())
    y = list(xy6[layer].values())
    plt.plot(x, y, color=color, label=f'6Q - {layer} layer', ls="-", marker="o")
    plt.xlabel("No. of P-layers")
    plt.ylabel("No. of Minimization Iterations")
    plt.legend()
plt.savefig(save_path+f"/6_all_shots-solution.eps", format='eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
for layer, color in zip(layers, colors):
    plt.figure()
    x = list(xy16[layer].keys())
    y = list(xy16[layer].values())
    plt.plot(x, y, color=color, label=f'16Q - {layer} layer', ls="-", marker="o")
    plt.xlabel("No. of P-layers")
    plt.ylabel("No. of Minimization Iterations")
    plt.savefig(save_path+f"/16_{layer}_shots-solution.eps", format='eps')
    plt.legend()

plt.figure()
for layer, color in zip(layers, colors):
    x = list(xy16[layer].keys())
    y = list(xy16[layer].values())
    plt.plot(x, y, color=color, label=f'16Q - {layer} layer', ls="-", marker="o")
    plt.xlabel("No. of P-layers")
    plt.ylabel("No. of Minimization Iterations")
    plt.legend()
plt.savefig(save_path+f"/16_all_shots-solution.eps", format='eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
for layer, color in zip(layers, colors):
    plt.figure()
    x = list(xy24[layer].keys())
    y = list(xy24[layer].values())
    plt.plot(x, y, color=color, label=f'24Q - {layer} layer', ls="-", marker="o")
    plt.xlabel("No. of P-layers")
    plt.ylabel("No. of Minimization Iterations")
    plt.savefig(save_path+f"/24_{layer}_shots-solution.eps", format='eps')
    plt.legend()

plt.figure()
for layer, color in zip(layers, colors):
    x = list(xy24[layer].keys())
    y = list(xy24[layer].values())
    plt.plot(x, y, color=color, label=f'24Q - {layer} layer', ls="-", marker="o")
    plt.xlabel("No. of P-layers")
    plt.ylabel("No. of Minimization Iterations")
    plt.legend()
plt.savefig(save_path+f"/24_all_shots-solution.eps", format='eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
for layer in layers:
    plt.figure()
    x = list(xy6[layer].keys())
    y = list(xy6[layer].values())
    plt.plot(x, y, color=colors[0], label=f'6Q - {layer} layer', ls ="-", marker="o")
    
    x16 = list(xy16[layer].keys())
    y16 = list(xy16[layer].values())
    plt.plot(x16, y16, color=colors[1], label=f'16Q - {layer} layer', ls ="-", marker="o")
    
    x24 = list(xy24[layer].keys())
    y24 = list(xy24[layer].values())
    plt.plot(x24, y24, color=colors[2], label=f'24Q - {layer} layer', ls ="-", marker="o")
    plt.xlabel("No. of P-layers")
    plt.ylabel("No. of Minimization Iterations")
    plt.savefig(save_path+f"/all_{layer}_shots-solution.eps", format='eps')
    plt.legend()
