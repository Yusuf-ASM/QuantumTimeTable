# %%
import os
import json
import matplotlib.pyplot as plt

# %%
save_path = "./new/p_solutions"
shots = [5120, 10240, 20480, 30720]
colors = ["black", "blue", "crimson","teal"] 

path = "../results/json/simulation/6"
files = os.listdir(path)
files.sort()
temp = files.pop(0)
files.append(temp)
for i in range(len(files)):
    files[i] = path+"/"+files[i]

path = "../results/json/simulation/16"
files16 = os.listdir(path)
files16.sort()
temp = files16.pop(0)
files16.append(temp)
for i in range(len(files)):
    files16[i] = path+"/"+files16[i]

path = "../results/json/simulation/24"
files24 = os.listdir(path)
files24.sort()
temp = files24.pop(0)
files24.append(temp)
for i in range(len(files)):
    files24[i] = path+"/"+files24[i]

for i in files:
    print(i)
# Out:
# ../results/json/simulation/6/2_1_1_10240_3_simulation.json
# ../results/json/simulation/6/2_1_1_10240_5_simulation.json
# ../results/json/simulation/6/2_1_1_10240_7_simulation.json
# ../results/json/simulation/6/2_1_1_20480_10_simulation.json
# ../results/json/simulation/6/2_1_1_20480_3_simulation.json
# ../results/json/simulation/6/2_1_1_20480_5_simulation.json
# ../results/json/simulation/6/2_1_1_20480_7_simulation.json
# ../results/json/simulation/6/2_1_1_30720_10_simulation.json
# ../results/json/simulation/6/2_1_1_30720_3_simulation.json
# ../results/json/simulation/6/2_1_1_30720_5_simulation.json
# ../results/json/simulation/6/2_1_1_30720_7_simulation.json
# ../results/json/simulation/6/2_1_1_5120_10_simulation.json
# ../results/json/simulation/6/2_1_1_5120_3_simulation.json
# ../results/json/simulation/6/2_1_1_5120_5_simulation.json
# ../results/json/simulation/6/2_1_1_5120_7_simulation.json
# ../results/json/simulation/6/2_1_1_10240_10_simulation.json

# %%
results = []
results16 = []
results24 = []
for i in range(len(files)):
    results.append(json.load(open(str(files[i]))))
    results16.append(json.load(open(str(files16[i]))))
    results24.append(json.load(open(str(files24[i]))))

# %%
xy6 = {5120: {3: 0, 5: 0, 7: 0, 10: 0}, 10240: {3: 0, 5: 0, 7: 0, 10: 0},
       20480: {3: 0, 5: 0, 7: 0, 10: 0}, 30720: {3: 0, 5: 0, 7: 0, 10: 0}}
xy16 = {5120: {3: 0, 5: 0, 7: 0, 10: 0}, 10240: {3: 0, 5: 0, 7: 0, 10: 0},
        20480: {3: 0, 5: 0, 7: 0, 10: 0}, 30720: {3: 0, 5: 0, 7: 0, 10: 0}}
xy24 = {5120: {3: 0, 5: 0, 7: 0, 10: 0}, 10240: {3: 0, 5: 0, 7: 0, 10: 0},
        20480: {3: 0, 5: 0, 7: 0, 10: 0}, 30720: {3: 0, 5: 0, 7: 0, 10: 0}}


for i in results:
    if i['solution_cost'] == 0:
        xy6[i["shots"]][i['layers']] = i["solution_count"]/i['shots']

for i in results16:
    if i['solution_cost'] == 0:
        xy16[i["shots"]][i['layers']] = i["solution_count"]/i['shots']

for i in results24:
    if i['solution_cost'] == 0:
        xy24[i["shots"]][i['layers']] = i["solution_count"]/i['shots']

# %%
for shot, color in zip(shots, colors):
    plt.figure()
    x = list(xy6[shot].keys())
    y = list(xy6[shot].values())
    plt.plot(x, y, color=color, label=f'6Q - {shot} shot', ls="-", marker="o")
    plt.xlabel("No. of P-layers")
    plt.ylabel("No. of Minimization Iterations")
    plt.savefig(save_path+f"/6_{shot}_p-solution.eps", format='eps')
    plt.legend()

plt.figure()
for shot, color in zip(shots, colors):
    x = list(xy6[shot].keys())
    y = list(xy6[shot].values())
    plt.plot(x, y, color=color, label=f'6Q - {shot} shot', ls="-", marker="o")
    plt.xlabel("No. of P-layers")
    plt.ylabel("No. of Minimization Iterations")
    plt.legend()
plt.savefig(save_path+f"/6_all_p-solution.eps", format='eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
for shot, color in zip(shots, colors):
    plt.figure()
    x = list(xy16[shot].keys())
    y = list(xy16[shot].values())
    plt.plot(x, y, color=color, label=f'16Q - {shot} shot', ls="-", marker="o")
    plt.xlabel("No. of P-layers")
    plt.ylabel("No. of Minimization Iterations")
    plt.savefig(save_path+f"/16_{shot}_p-solution.eps", format='eps')
    plt.legend()

plt.figure()
for shot, color in zip(shots, colors):
    x = list(xy16[shot].keys())
    y = list(xy16[shot].values())
    plt.plot(x, y, color=color, label=f'16Q - {shot} shot', ls="-", marker="o")
    plt.xlabel("No. of P-layers")
    plt.ylabel("No. of Minimization Iterations")
    plt.legend()
plt.savefig(save_path+f"/16_all_p-solution.eps", format='eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
for shot, color in zip(shots, colors):
    plt.figure()
    x = list(xy24[shot].keys())
    y = list(xy24[shot].values())
    plt.plot(x, y, color=color, label=f'24Q - {shot} shot', ls="-", marker="o")
    plt.xlabel("No. of P-layers")
    plt.ylabel("No. of Minimization Iterations")
    plt.savefig(save_path+f"/24_{shot}_p-solution.eps", format='eps')
    plt.legend()

plt.figure()
for shot, color in zip(shots, colors):
    x = list(xy24[shot].keys())
    y = list(xy24[shot].values())
    plt.plot(x, y, color=color, label=f'24Q - {shot} shot', ls="-", marker="o")
    plt.xlabel("No. of P-layers")
    plt.ylabel("No. of Minimization Iterations")
    plt.legend()
plt.savefig(save_path+f"/24_all_p-solution.eps", format='eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
for shot in shots:
    plt.figure()
    x = list(xy6[shot].keys())
    y = list(xy6[shot].values())
    plt.plot(x, y, color=colors[0], label=f'6Q - {shot} shot', ls ="-", marker="o")
    
    x16 = list(xy16[shot].keys())
    y16 = list(xy16[shot].values())
    plt.plot(x16, y16, color=colors[1], label=f'16Q - {shot} shot', ls ="-", marker="o")
    
    x24 = list(xy24[shot].keys())
    y24 = list(xy24[shot].values())
    plt.plot(x24, y24, color=colors[2], label=f'24Q - {shot} shot', ls ="-", marker="o")
    plt.xlabel("No. of P-layers")
    plt.ylabel("No. of Minimization Iterations")
    plt.savefig(save_path+f"/all_{shot}_p-iteration.eps", format='eps')

    plt.legend()
